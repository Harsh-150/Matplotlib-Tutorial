# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(10,60,(50))
print(x)
# Out:
# [36 40 22 29 30 54 54 54 22 15 33 26 48 17 40 38 30 23 39 36 47 17 31 41
#  22 19 23 21 59 49 33 13 37 23 44 44 23 21 41 59 52 53 10 53 35 37 11 12
#  44 48]

# %%
num = [36, 40, 22, 29, 30, 54, 54, 54, 22, 15, 33, 26, 48, 17, 40, 38, 30, 23, 39, 36, 47, 17, 31, 41,
 22, 19, 23, 21, 59, 49, 33, 13, 37, 23, 44, 44, 23, 21, 41, 59, 52, 53, 10, 53, 35, 37, 11, 12,
 44, 48]

l = [10,20,30,40,50,60]

plt.hist(num, color="g", edgecolor="w", bins=l)
plt.title("Histogram")
plt.xlabel("Independent variable")
plt.ylabel("Dependent variable")
plt.show()

# %%
num = [36, 40, 22, 29, 30, 54, 54, 54, 22, 15, 33, 26, 48, 17, 40, 38, 30, 23, 39, 36, 47, 17, 31, 41,
 22, 19, 23, 21, 59, 49, 33, 13, 37, 23, 44, 44, 23, 21, 41, 59, 52, 53, 10, 53, 35, 37, 11, 12,
 44, 48]

l = [10,20,30,40,50,60]

plt.hist(num, "auto", (0,100), edgecolor="w")
plt.title("Histogram")
plt.xlabel("Independent variable")
plt.ylabel("Dependent variable")
plt.show()

# %%
num = [36, 40, 22, 29, 30, 54, 54, 54, 22, 15, 33, 26, 48, 17, 40, 38, 30, 23, 39, 36, 47, 17, 31, 41,
 22, 19, 23, 21, 59, 49, 33, 13, 37, 23, 44, 44, 23, 21, 41, 59, 52, 53, 10, 53, 35, 37, 11, 12,
 44, 48]

l = [10,20,30,40,50,60]

plt.hist(num, cumulative=-1, edgecolor="w")
plt.title("Histogram")
plt.xlabel("Independent variable")
plt.ylabel("Dependent variable")
plt.show()

# %%
num = [36, 40, 22, 29, 30, 54, 54, 54, 22, 15, 33, 26, 48, 17, 40, 38, 30, 23, 39, 36, 47, 17, 31, 41,
 22, 19, 23, 21, 59, 49, 33, 13, 37, 23, 44, 44, 23, 21, 41, 59, 52, 53, 10, 53, 35, 37, 11, 12,
 44, 48]

l = [10,20,30,40,50,60]

plt.hist(num, "auto", (0,100), edgecolor="w",align="mid", rwidth=0.8)
plt.title("Histogram")
plt.xlabel("Independent variable")
plt.ylabel("Dependent variable")
plt.show()

# %%
num = [36, 40, 22, 29, 30, 54, 54, 54, 22, 15, 33, 26, 48, 17, 40, 38, 30, 23, 39, 36, 47, 17, 31, 41,
 22, 19, 23, 21, 59, 49, 33, 13, 37, 23, 44, 44, 23, 21, 41, 59, 52, 53, 10, 53, 35, 37, 11, 12,
 44, 48]

l = [10,20,30,40,50,60]

plt.hist(num, "auto", (0,100), edgecolor="m", histtype="step")
plt.title("Histogram")
plt.xlabel("Independent variable")
plt.ylabel("Dependent variable")
plt.show()

# %%
num = [36, 40, 22, 29, 30, 54, 54, 54, 22, 15, 33, 26, 48, 17, 40, 38, 30, 23, 39, 36, 47, 17, 31, 41,
 22, 19, 23, 21, 59, 49, 33, 13, 37, 23, 44, 44, 23, 21, 41, 59, 52, 53, 10, 53, 35, 37, 11, 12,
 44, 48]

l = [10,20,30,40,50,60]

plt.hist(num, "auto", (0,100), edgecolor="w",orientation="horizontal")
plt.title("Histogram")
plt.xlabel("Independent variable")
plt.ylabel("Dependent variable")
plt.show()

# %%
num = [36, 40, 22, 29, 30, 54, 54, 54, 22, 15, 33, 26, 48, 17, 40, 38, 30, 23, 39, 36, 47, 17, 31, 41,
 22, 19, 23, 21, 59, 49, 33, 13, 37, 23, 44, 44, 23, 21, 41, 59, 52, 53, 10, 53, 35, 37, 11, 12,
 44, 48]

l = [10,20,30,40,50,60]

plt.hist(num, cumulative=-1, edgecolor="w", log=True,label="Log values")
plt.title("Histogram")
plt.xlabel("Independent variable")
plt.ylabel("Dependent variable")
plt.legend()
plt.show()

# %%
num = [36, 40, 22, 29, 30, 54, 54, 54, 22, 15, 33, 26, 48, 17, 40, 38, 30, 23, 39, 36, 47, 17, 31, 41,
 22, 19, 23, 21, 59, 49, 33, 13, 37, 23, 44, 44, 23, 21, 41, 59, 52, 53, 10, 53, 35, 37, 11, 12,
 44, 48]

l = [10,20,30,40,50,60]

plt.hist(num, cumulative=-1, edgecolor="w", log=True,label="Log values")
plt.title("Histogram")
plt.xlabel("Independent variable")
plt.ylabel("Dependent variable")
plt.axvline(45,color="g",label="line")
plt.legend()
plt.grid()
plt.show()
